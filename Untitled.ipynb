# %%
print(sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(sklearn.__version__)
#
# NameError: name 'sklearn' is not defined

# %%
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 1.4.1.post1

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#
# ...
