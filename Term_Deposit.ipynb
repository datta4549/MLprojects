# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('TermDeposit.xlsx - Sheet1.csv')

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
sns.pairplot(df)
# Out:
# C:\Users\naiko\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['age'].describe()
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
sns.boxplot(df['age'])
plt.show()

# %%
sns.histplot(df['age'], bins=50, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.hist(bins=20, figsize=(14,10))
plt.show()

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
sns.countplot(x='job',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='job', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='marital',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='marital', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='education', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='education', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['default'].value_counts()
# Out:
# default
# no     44396
# yes      815
# Name: count, dtype: int64

# %%
sns.countplot(x='default', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='default', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
#count of no is high so we drop this feature

# %%
df.drop(columns=['default'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age           job  marital  education  balance housing loan  contact  day  \
# 0   58    management  married   tertiary     2143     yes   no  unknown    5
# 1   44    technician   single  secondary       29     yes   no  unknown    5
# 2   33  entrepreneur  married  secondary        2     yes  yes  unknown    5
# 3   47   blue-collar  married    unknown     1506     yes   no  unknown    5
# 4   33       unknown   single    unknown        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
# 2   may        76         1     -1         0  unknown  no
# 3   may        92         1     -1         0  unknown  no
# 4   may       198         1     -1         0  unknown  no

# %%
sns.countplot(x='loan', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='housing', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='loan', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='contact', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='contact', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head(2)
# Out:
#    age         job  marital  education  balance housing loan  contact  day  \
# 0   58  management  married   tertiary     2143     yes   no  unknown    5
# 1   44  technician   single  secondary       29     yes   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
sns.barplot(x='job', y='age', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x='job', y='age', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.pie(labels=['yes','no'], x=df['housing'].value_counts().values,autopct='%0.2f%%', pctdistance=0.8)
plt.title('Housing Loan')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
 
# Current Figure ( plt.gcf() ) 
# --> Current Axis ( gca() ) 
# --> add the hole 
plt.gcf().gca().add_artist(hole)
 
plt.show()

# %%
plt.pie(labels=['yes','no'], x=df['loan'].value_counts().values,autopct='%0.2f%%', pctdistance=0.82)
plt.title('Personal Loan')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
 
# Current Figure ( plt.gcf() ) 
# --> Current Axis ( gca() ) 
# --> add the hole 
plt.gcf().gca().add_artist(hole)
 
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'balance', 'housing', 'loan',
#        'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'y'],
#       dtype='object')

# %%
sns.countplot(x='month', data=df)
plt.xticks(rotation='vertical')
plt.title('Last contact Month')
plt.show()

# %%
sns.countplot(x='month', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.title('Last contact Month')
plt.show()

# %%
sns.countplot(x='poutcome', data=df)
plt.xticks(rotation='vertical')
plt.title('outcome of the previous marketing campaign')
plt.show()

# %%
sns.countplot(x='poutcome', hue='y', data=df)
plt.xticks(rotation='vertical')
plt.title('outcome of the previous marketing campaign')
plt.show()

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
plt.pie(labels=df['poutcome'].unique(), x=df['poutcome'].value_counts().values,autopct='%0.2f%%', pctdistance=0.83)
plt.title('outcome of the previous marketing campaign')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
 
plt.gcf().gca().add_artist(hole)
 
plt.show()

# %%
plt.pie(labels=df['y'].unique(), x=df['y'].value_counts().values,autopct='%0.2f%%', pctdistance=0.83)
plt.title('Term Deposit')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
 

plt.gcf().gca().add_artist(hole)
 
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   balance    45211 non-null  int64
#  5   housing    45211 non-null  object
#  6   loan       45211 non-null  object
#  7   contact    45211 non-null  object
#  8   day        45211 non-null  int64
#  9   month      45211 non-null  object
#  10  duration   45211 non-null  int64
#  11  campaign   45211 non-null  int64
#  12  pdays      45211 non-null  int64
#  13  previous   45211 non-null  int64
#  14  poutcome   45211 non-null  object
#  15  y          45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
df['balance'].describe()
# Out:
# count     45211.000000
# mean       1362.272058
# std        3044.765829
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
plt.figure(figsize=(10, 15))
sns.boxplot(df.balance)
plt.show()

# %%
#we see alot of outliers in 'balance' feature

# %% [markdown]
# # handling outliers with IQR method

# %%
Q1 = df['balance'].quantile(0.25)
Q3 = df['balance'].quantile(0.75)
print(f'Q1:{Q1} Q3:{Q3}')
# Out:
# Q1:72.0 Q3:1428.0

# %%
IQR = Q3 - Q1
print(f"IQR:{IQR}")
# Out:
# IQR:1356.0

# %%
LL = Q1 - 1.5 * (IQR)
print(LL)
# Out:
# -1962.0

# %%
HL = Q3 + 1.5 * (IQR)
print(HL)
# Out:
# 3462.0

# %%
(df['balance'] > 3462.0) | (df['balance'] < -1962.0)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208     True
# 45209    False
# 45210    False
# Name: balance, Length: 45211, dtype: bool

# %%
outlier_count = df[(df['balance'] > 3462.0) | (df['balance'] < -1962.0)].shape[0]
outlier_perc = (outlier_count * 100)/df.shape[0]

print(f"# of Outliers: {outlier_count} | % of Outliers: {outlier_perc}")
# Out:
# # of Outliers: 4729 | % of Outliers: 10.459843843312468

# %% [markdown]
# # percentile approach to remove outliers

# %%
# Define the percentile threshold
percentile_threshold = 95

# Calculate the specified percentile
percentile_value = int(np.percentile(df['balance'], percentile_threshold))

# Identify potential outliers
outliers = df[df['balance'] > percentile_value]

print(f'{percentile_threshold}th Percentile Value: {percentile_value}')
print(f'Number of Potential Outliers: {len(outliers)}')
# Out:
# 95th Percentile Value: 5768
# Number of Potential Outliers: 2260

# %%
df = df[df['balance'] <= 5768]

# %%
plt.figure(figsize=(10, 15))
sns.boxplot(df.balance)
plt.show()

# %%
# Define the percentile threshold
percentile_threshold = 5

# Calculate the specified percentile
percentile_value = int(np.percentile(df['balance'], percentile_threshold))

# Identify potential outliers
outliers = df[df['balance'] < percentile_value]

print(f'{percentile_threshold}th Percentile Value: {percentile_value}')
print(f'Number of Potential Outliers: {len(outliers)}')
# Out:
# 5th Percentile Value: -191
# Number of Potential Outliers: 2142

# %%
df = df[df['balance'] > -191]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(df.balance)
plt.show()

# %%
job_mean = df.groupby('job')['balance'].mean()

# %%
job_mean
# Out:
# job
# admin.            875.068138
# blue-collar       850.162454
# entrepreneur      851.204461
# housemaid         921.747215
# management       1038.066421
# retired          1235.769682
# self-employed     973.196779
# services          801.743727
# student           956.353273
# technician        894.962615
# unemployed        939.163575
# unknown          1133.784906
# Name: balance, dtype: float64

# %%
sns.barplot(x='job', y='balance', data=df)
plt.xticks(rotation='vertical')
plt.title('Avg Balance by job')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'balance', 'housing', 'loan',
#        'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'y'],
#       dtype='object')

# %%
df['effects_of_duration'] = np.where(df['duration'] > df['duration'].mean(), 'Above_Average_Duration','Below_Average_Duration')

# %%
df.head()
# Out:
#    age           job  marital  education  balance housing loan  contact  day  \
# 0   58    management  married   tertiary     2143     yes   no  unknown    5
# 1   44    technician   single  secondary       29     yes   no  unknown    5
# 2   33  entrepreneur  married  secondary        2     yes  yes  unknown    5
# 3   47   blue-collar  married    unknown     1506     yes   no  unknown    5
# 4   33       unknown   single    unknown        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y  \
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
# 2   may        76         1     -1         0  unknown  no
# 3   may        92         1     -1         0  unknown  no
# 4   may       198         1     -1         0  unknown  no
#
#       effects_of_duration
# 0  Above_Average_Duration
# 1  Below_Average_Duration
# 2  Below_Average_Duration
# 3  Below_Average_Duration
# ...

# %%
sns.countplot(x='effects_of_duration', hue = 'y',  data = df)
#plt.xticks(rotation='vertical')
plt.title('effect of duration on Term Deposit')
plt.show()

# %%
df['effects_of_balance'] = np.where(df['balance'] > df['balance'].mean(), 'Above_Average_balance','Below_Average_balance')

# %%
df.head()
# Out:
#    age           job  marital  education  balance housing loan  contact  day  \
# 0   58    management  married   tertiary     2143     yes   no  unknown    5
# 1   44    technician   single  secondary       29     yes   no  unknown    5
# 2   33  entrepreneur  married  secondary        2     yes  yes  unknown    5
# 3   47   blue-collar  married    unknown     1506     yes   no  unknown    5
# 4   33       unknown   single    unknown        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y  \
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
# 2   may        76         1     -1         0  unknown  no
# 3   may        92         1     -1         0  unknown  no
# 4   may       198         1     -1         0  unknown  no
#
#       effects_of_duration     effects_of_balance
# 0  Above_Average_Duration  Above_Average_balance
# 1  Below_Average_Duration  Below_Average_balance
# ...

# %%
sns.countplot(x='effects_of_balance', hue = 'y',  data = df)
#plt.xticks(rotation='vertical')
plt.title('effect of duration on Y')
plt.show()

# %%
df.head()
# Out:
#    age           job  marital  education  balance housing loan  contact  day  \
# 0   58    management  married   tertiary     2143     yes   no  unknown    5
# 1   44    technician   single  secondary       29     yes   no  unknown    5
# 2   33  entrepreneur  married  secondary        2     yes  yes  unknown    5
# 3   47   blue-collar  married    unknown     1506     yes   no  unknown    5
# 4   33       unknown   single    unknown        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y  \
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
# 2   may        76         1     -1         0  unknown  no
# 3   may        92         1     -1         0  unknown  no
# 4   may       198         1     -1         0  unknown  no
#
#       effects_of_duration     effects_of_balance
# 0  Above_Average_Duration  Above_Average_balance
# 1  Below_Average_Duration  Below_Average_balance
# ...

# %%
numeric_df = df.select_dtypes(exclude="object")

# %%
df
# Out:
#        age           job   marital  education  balance housing loan  \
# 0       58    management   married   tertiary     2143     yes   no
# 1       44    technician    single  secondary       29     yes   no
# 2       33  entrepreneur   married  secondary        2     yes  yes
# 3       47   blue-collar   married    unknown     1506     yes   no
# 4       33       unknown    single    unknown        1      no   no
# ...    ...           ...       ...        ...      ...     ...  ...
# 45206   51    technician   married   tertiary      825      no   no
# 45207   71       retired  divorced    primary     1729      no   no
# 45208   72       retired   married  secondary     5715      no   no
# 45209   57   blue-collar   married  secondary      668      no   no
# 45210   37  entrepreneur   married  secondary     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40800 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  40800 non-null  int64
#  1   job                  40800 non-null  object
#  2   marital              40800 non-null  object
#  3   education            40800 non-null  object
#  4   balance              40800 non-null  int64
#  5   housing              40800 non-null  object
#  6   loan                 40800 non-null  object
#  7   contact              40800 non-null  object
#  8   day                  40800 non-null  int64
#  9   month                40800 non-null  object
#  10  duration             40800 non-null  int64
#  11  campaign             40800 non-null  int64
#  12  pdays                40800 non-null  int64
#  13  previous             40800 non-null  int64
#  14  poutcome             40800 non-null  object
# ...

# %%
df.head(2)
# Out:
#    age         job  marital  education  balance housing loan  contact  day  \
# 0   58  management  married   tertiary     2143     yes   no  unknown    5
# 1   44  technician   single  secondary       29     yes   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y  \
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
#
#       effects_of_duration     effects_of_balance
# 0  Above_Average_Duration  Above_Average_balance
# 1  Below_Average_Duration  Below_Average_balance

# %%
import a x yzd;fkzf

# %%
from sklearn.preprocessing import LabelEncoder
cols=['y']
# Encode labels of object dtype multiple columns at once 
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    age           job  marital  education  balance housing loan  contact  day  \
# 0   58    management  married   tertiary     2143     yes   no  unknown    5
# 1   44    technician   single  secondary       29     yes   no  unknown    5
# 2   33  entrepreneur  married  secondary        2     yes  yes  unknown    5
# 3   47   blue-collar  married    unknown     1506     yes   no  unknown    5
# 4   33       unknown   single    unknown        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome  y  \
# 0   may       261         1     -1         0  unknown  0
# 1   may       151         1     -1         0  unknown  0
# 2   may        76         1     -1         0  unknown  0
# 3   may        92         1     -1         0  unknown  0
# 4   may       198         1     -1         0  unknown  0
#
#       effects_of_duration     effects_of_balance
# 0  Above_Average_Duration  Above_Average_balance
# 1  Below_Average_Duration  Below_Average_balance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40800 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  40800 non-null  int64
#  1   job                  40800 non-null  object
#  2   marital              40800 non-null  object
#  3   education            40800 non-null  object
#  4   balance              40800 non-null  int64
#  5   housing              40800 non-null  object
#  6   loan                 40800 non-null  object
#  7   contact              40800 non-null  object
#  8   day                  40800 non-null  int64
#  9   month                40800 non-null  object
#  10  duration             40800 non-null  int64
#  11  campaign             40800 non-null  int64
#  12  pdays                40800 non-null  int64
#  13  previous             40800 non-null  int64
#  14  poutcome             40800 non-null  object
# ...

# %%
sns.heatmap(data=numeric_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
cols=['job','marital','housing','loan','contact']
# Encode labels of object dtype multiple columns at once 
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day month  \
# 0   58    4        1   tertiary     2143        1     0        2    5   may
# 1   44    9        2  secondary       29        1     0        2    5   may
# 2   33    2        1  secondary        2        1     1        2    5   may
# 3   47    1        1    unknown     1506        1     0        2    5   may
# 4   33   11        2    unknown        1        0     0        2    5   may
#
#    duration  campaign  pdays  previous poutcome  y     effects_of_duration  \
# 0       261         1     -1         0  unknown  0  Above_Average_Duration
# 1       151         1     -1         0  unknown  0  Below_Average_Duration
# 2        76         1     -1         0  unknown  0  Below_Average_Duration
# 3        92         1     -1         0  unknown  0  Below_Average_Duration
# 4       198         1     -1         0  unknown  0  Below_Average_Duration
#
#       effects_of_balance
# 0  Above_Average_balance
# ...

# %%
df['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %% [markdown]
# # encoding education feature

# %%
df['education'] = df['education'].map({'unknown':0,'primary':1,'secondary':2,"tertiary":3})

# %%
df.head(2)
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day month  \
# 0   58    4        1          3     2143        1     0        2    5   may
# 1   44    9        2          2       29        1     0        2    5   may
#
#    duration  campaign  pdays  previous poutcome  y     effects_of_duration  \
# 0       261         1     -1         0  unknown  0  Above_Average_Duration
# 1       151         1     -1         0  unknown  0  Below_Average_Duration
#
#       effects_of_balance
# 0  Above_Average_balance
# 1  Below_Average_balance

# %% [markdown]
# # encoding Month feature

# %%
df['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
df['month'] = df['month'].map({'jan':1,'feb':2,'mar':3,"apr":4,'may':5,'jun':6,'jul':7,"aug":8,'sep':9,'oct':10,'nov':11,"dec":12})
df.head(2)
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
#
#    duration  campaign  pdays  previous poutcome  y     effects_of_duration  \
# 0       261         1     -1         0  unknown  0  Above_Average_Duration
# 1       151         1     -1         0  unknown  0  Below_Average_Duration
#
#       effects_of_balance
# 0  Above_Average_balance
# 1  Below_Average_balance

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
df['poutcome'] = df['poutcome'].map({'failure':0,'success':1,'unknown':3,"other":4})

# %%
df.head()
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
# 2   33    2        1          2        2        1     1        2    5      5
# 3   47    1        1          0     1506        1     0        2    5      5
# 4   33   11        2          0        1        0     0        2    5      5
#
#    duration  campaign  pdays  previous  poutcome  y     effects_of_duration  \
# 0       261         1     -1         0         3  0  Above_Average_Duration
# 1       151         1     -1         0         3  0  Below_Average_Duration
# 2        76         1     -1         0         3  0  Below_Average_Duration
# 3        92         1     -1         0         3  0  Below_Average_Duration
# 4       198         1     -1         0         3  0  Below_Average_Duration
#
#       effects_of_balance
# ...

# %%
df.rename(columns={'effects_of_duration':'Duration','effects_of_balance':'Balance'},inplace=True)

# %%
df.head()
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
# 2   33    2        1          2        2        1     1        2    5      5
# 3   47    1        1          0     1506        1     0        2    5      5
# 4   33   11        2          0        1        0     0        2    5      5
#
#    duration  campaign  pdays  previous  poutcome  y                Duration  \
# 0       261         1     -1         0         3  0  Above_Average_Duration
# 1       151         1     -1         0         3  0  Below_Average_Duration
# 2        76         1     -1         0         3  0  Below_Average_Duration
# 3        92         1     -1         0         3  0  Below_Average_Duration
# 4       198         1     -1         0         3  0  Below_Average_Duration
#
#                  Balance
# ...

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
# 2   33    2        1          2        2        1     1        2    5      5
# 3   47    1        1          0     1506        1     0        2    5      5
# 4   33   11        2          0        1        0     0        2    5      5
#
#    duration  campaign  pdays  previous  poutcome  y                Duration  \
# 0       261         1     -1         0         3  0  Above_Average_Duration
# 1       151         1     -1         0         3  0  Below_Average_Duration
# 2        76         1     -1         0         3  0  Below_Average_Duration
# 3        92         1     -1         0         3  0  Below_Average_Duration
# 4       198         1     -1         0         3  0  Below_Average_Duration
#
#                  Balance
# ...

# %%
df1.drop(columns=['Duration','Balance'],inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40800 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        40800 non-null  int64
#  1   job        40800 non-null  int32
#  2   marital    40800 non-null  int32
#  3   education  40800 non-null  int64
#  4   balance    40800 non-null  int64
#  5   housing    40800 non-null  int32
#  6   loan       40800 non-null  int32
#  7   contact    40800 non-null  int32
#  8   day        40800 non-null  int64
#  9   month      40800 non-null  int64
#  10  duration   40800 non-null  int64
#  11  campaign   40800 non-null  int64
#  12  pdays      40800 non-null  int64
#  13  previous   40800 non-null  int64
#  14  poutcome   40800 non-null  int64
#  15  y          40800 non-null  int32
# dtypes: int32(6), int64(10)
# memory usage: 5.4 MB

# %%
x = df1.drop(['y'],axis=1)
print(x.shape)
x.head()
# Out:
# (40800, 15)
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
# 2   33    2        1          2        2        1     1        2    5      5
# 3   47    1        1          0     1506        1     0        2    5      5
# 4   33   11        2          0        1        0     0        2    5      5
#
#    duration  campaign  pdays  previous  poutcome
# 0       261         1     -1         0         3
# 1       151         1     -1         0         3
# 2        76         1     -1         0         3
# 3        92         1     -1         0         3
# 4       198         1     -1         0         3

# %%
y = df1['y']
print(y.shape)
y.head()
# Out:
# (40800,)
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int32

# %%
y.value_counts()
# Out:
# y
# 0    35971
# 1     4829
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.8,random_state=7)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (32640, 15)
# (8160, 15)
# (32640,)
# (8160,)

# %%
y_train.value_counts()
# Out:
# y
# 0    28801
# 1     3839
# Name: count, dtype: int64

# %%
#we can see that 1 is minority class and 0 is the majority class so we have imbalance data

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
x_train=rs.fit_transform(x_train)
x_test=rs.transform(x_test)

# %% [markdown]
# # handling imbalance data

# %%
#USING SMOTE TECHNIQUE ON X_TRAIN AND Y_TRAIN TO HANDLE IMBALANCE DATA

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=11)
x_over, y_over = sm.fit_resample(x_train,y_train)

# %%
print(x_over.shape)
print(y_over.shape)
# Out:
# (57602, 15)
# (57602,)

# %%
y_over.value_counts()
# Out:
# y
# 1    28801
# 0    28801
# Name: count, dtype: int64

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(x_over,y_over)
pred_lreg = log_reg.predict(x_test)

# %%
pred_train = log_reg.predict(x_over)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,pred_lreg, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lreg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88      7170
#            1       0.37      0.78      0.50       990
#
#     accuracy                           0.81      8160
#    macro avg       0.67      0.80      0.69      8160
# weighted avg       0.89      0.81      0.84      8160

# %%
from sklearn.metrics import classification_report
print(classification_report(y_over,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81     28801
#            1       0.81      0.82      0.82     28801
#
#     accuracy                           0.81     57602
#    macro avg       0.81      0.81      0.81     57602
# weighted avg       0.81      0.81      0.81     57602

# %%
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB  
nb_model = GaussianNB()
nb_model.fit(x_over, y_over)
pred = nb_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(nb_model,x_test,y_test)
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      7170
#            1       0.27      0.82      0.40       990
#
#     accuracy                           0.70      8160
#    macro avg       0.62      0.75      0.60      8160
# weighted avg       0.88      0.70      0.75      8160

# %%
pred_train = nb_model.predict(x_over)

# %%
print(classification_report(y_over,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73     28801
#            1       0.72      0.84      0.78     28801
#
#     accuracy                           0.76     57602
#    macro avg       0.76      0.76      0.75     57602
# weighted avg       0.76      0.76      0.75     57602

# %%
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV

fit_dt = DecisionTreeClassifier(random_state=17)

param_dist = {'max_depth': [2, 3, 4,5,6,7,8,9,10],
              'criterion': ['gini', 'entropy'],
             'max_leaf_nodes':[4,6,8,10,12,14]}

cv_dt = GridSearchCV(fit_dt, cv = 15,
                     param_grid=param_dist)

cv_dt.fit(x_over, y_over)

print(cv_dt.best_score_)

y_pred=cv_dt.predict(x_test)

accuracy_score = accuracy_score(y_test,y_pred)
print('Accuracy Score for model for test data is: ',accuracy_score)
# Out:
# 0.8355285534004455
# Accuracy Score for model for test data is:  0.8247549019607843

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(cv_dt,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89      7170
#            1       0.39      0.76      0.51       990
#
#     accuracy                           0.82      8160
#    macro avg       0.67      0.80      0.70      8160
# weighted avg       0.89      0.82      0.85      8160

# %%
y_pred_train =cv_dt.predict(x_over)

# %%
print(classification_report(y_over,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83     28801
#            1       0.83      0.84      0.84     28801
#
#     accuracy                           0.84     57602
#    macro avg       0.84      0.84      0.84     57602
# weighted avg       0.84      0.84      0.84     57602

# %%
# RANDOM FOREST

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier #RandomForestRegressor

fit_rf = RandomForestClassifier(random_state=3)

# %%
# Providing the different values of hyperparameters
param_dist = {'max_depth': [2, 3, 4,6,8],
              'max_features': ['log2', 'sqrt'],
              'criterion': ['gini', 'entropy'],
             'n_estimators':[10,15,20,25,30]}

# Running gridsearchCV to check for all the different PnCs of these parameter values
cv_rf = GridSearchCV(fit_rf, cv =5,
                     param_grid=param_dist,error_score='raise')

#Fitting the train set , so that grid search is executed on this dataset
cv_rf.fit(x_over, y_over)

#Printing the best parameters by using best_params
print('Best Parameters using grid search: \n', cv_rf.best_params_)   #to get best Hyperparameters
# Out:
# Best Parameters using grid search:
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'n_estimators': 30}

# %%
print(cv_rf.best_score_)
# Out:
# 0.8897787780646935

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(cv_rf,x_test,y_test)
plt.show()

# %%
pred = cv_rf.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      7170
#            1       0.42      0.76      0.54       990
#
#     accuracy                           0.84      8160
#    macro avg       0.69      0.81      0.72      8160
# weighted avg       0.90      0.84      0.86      8160

# %%
pred_train = cv_rf.predict(x_over)

# %%
print(classification_report(y_over,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89     28801
#            1       0.87      0.94      0.90     28801
#
#     accuracy                           0.90     57602
#    macro avg       0.90      0.90      0.90     57602
# weighted avg       0.90      0.90      0.90     57602

# %%
# NEAREST NEIGHBORS

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

error = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,x_over,y_over,cv=5)
    error.append(1-score.mean())

# %%
plt.figure(figsize=(10,6))

plt.plot(range(1,40),error,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier()

param_dist = {'n_neighbors': [27,29,31,33,35,39],
              'metric': ['minkowski','manhattan']}
cv_knn = GridSearchCV(knn,cv=20,param_grid=param_dist)
cv_knn.fit(x_over,y_over)
# Out:
# GridSearchCV(cv=20, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['minkowski', 'manhattan'],
#                          'n_neighbors': [27, 29, 31, 33, 35, 39]})

# %%
pred = cv_knn.predict(x_test)
pred_train = cv_knn.predict(x_over)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(cv_knn,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,pred))
print('\n')
print(classification_report(y_over,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90      7170
#            1       0.42      0.80      0.55       990
#
#     accuracy                           0.84      8160
#    macro avg       0.70      0.82      0.73      8160
# weighted avg       0.90      0.84      0.86      8160
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90     28801
#            1       0.87      0.96      0.91     28801
#
#     accuracy                           0.90     57602
#    macro avg       0.91      0.90      0.90     57602
# weighted avg       0.91      0.90      0.90     57602

# %%
# SUPPORT VECTOR MACHINE

# %%
# SVC model
from sklearn.svm import SVC
svc = SVC(C=5, gamma='auto')

# Train the model
svc.fit(x_over, y_over)
# Out:
# SVC(C=5, gamma='auto')

# %%
pred = svc.predict(x_test)
pred_train = svc.predict(x_over)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(svc,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,pred))
print('\n')
print(classification_report(y_over,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      7170
#            1       0.42      0.73      0.53       990
#
#     accuracy                           0.84      8160
#    macro avg       0.69      0.79      0.72      8160
# weighted avg       0.89      0.84      0.86      8160
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     28801
#            1       0.89      0.94      0.91     28801
#
#     accuracy                           0.91     57602
#    macro avg       0.91      0.91      0.91     57602
# weighted avg       0.91      0.91      0.91     57602

# %% [markdown]
# # model 2

# %%
df2 = df1.copy()
df2.head()
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   58    4        1          3     2143        1     0        2    5      5
# 1   44    9        2          2       29        1     0        2    5      5
# 2   33    2        1          2        2        1     1        2    5      5
# 3   47    1        1          0     1506        1     0        2    5      5
# 4   33   11        2          0        1        0     0        2    5      5
#
#    duration  campaign  pdays  previous  poutcome  y
# 0       261         1     -1         0         3  0
# 1       151         1     -1         0         3  0
# 2        76         1     -1         0         3  0
# 3        92         1     -1         0         3  0
# 4       198         1     -1         0         3  0

# %%
y.value_counts()
# Out:
# y
# 0    35971
# 1     4829
# Name: count, dtype: int64

# %%
#performing SMOT technique on x & y

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=11)
x_new, y_new = sm.fit_resample(x,y)

# %%
y_new.value_counts()
# Out:
# y
# 0    35971
# 1    35971
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_new,y_new,train_size=0.8,random_state=7)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (57553, 15)
# (14389, 15)
# (57553,)
# (14389,)

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
x_train=rs.fit_transform(x_train)
x_test=rs.transform(x_test)

# %% [markdown]
# ##LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(x_train,y_train)
pred_lreg = log_reg.predict(x_test)

# %%
pred_train = log_reg.predict(x_train)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,pred_lreg, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lreg))
print('\n')
print(classification_report(y_train,pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      7199
#            1       0.84      0.87      0.85      7190
#
#     accuracy                           0.85     14389
#    macro avg       0.85      0.85      0.85     14389
# weighted avg       0.85      0.85      0.85     14389
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86     28772
#            1       0.84      0.88      0.86     28781
#
#     accuracy                           0.86     57553
#    macro avg       0.86      0.86      0.86     57553
# weighted avg       0.86      0.86      0.86     57553

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train,y_train)
y_test_predict = classifier.predict(x_test)
y_train_predict = classifier.predict(x_train)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_predict))
print("*****************************************************\n")
print(classification_report(y_train, y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.66      0.75      7199
#            1       0.73      0.91      0.81      7190
#
#     accuracy                           0.79     14389
#    macro avg       0.81      0.79      0.78     14389
# weighted avg       0.81      0.79      0.78     14389
#
# *****************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.66      0.76     28772
#            1       0.73      0.92      0.81     28781
#
#     accuracy                           0.79     57553
#    macro avg       0.81      0.79      0.78     57553
# weighted avg       0.81      0.79      0.78     57553

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_test_predict, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV

fit_dt = DecisionTreeClassifier(random_state=17)

param_dist = {'max_depth': [2, 3, 4,5,6,7,8,9,10],
              'criterion': ['gini', 'entropy'],
             'max_leaf_nodes':[4,6,8,10,12,14]}

cv_dt = GridSearchCV(fit_dt, cv = 10,
                     param_grid=param_dist)

cv_dt.fit(x_train, y_train)

print(cv_dt.best_score_)

y_pred=cv_dt.predict(x_test)

accuracy_score = accuracy_score(y_test,y_pred)
print('Accuracy Score for model for test data is: ',accuracy_score)
# Out:
# 0.8475839512307333
# Accuracy Score for model for test data is:  0.8452984919035375

# %%
print('Best Parameters using grid search: \n', cv_dt.best_params_)
# Out:
# Best Parameters using grid search:
#  {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 14}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
y_pred_train = cv_dt.predict(x_train)

# %%
print(classification_report(y_test, y_pred))
print("*****************************************************\n")
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      7199
#            1       0.83      0.87      0.85      7190
#
#     accuracy                           0.85     14389
#    macro avg       0.85      0.85      0.85     14389
# weighted avg       0.85      0.85      0.85     14389
#
# *****************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84     28772
#            1       0.83      0.88      0.85     28781
#
#     accuracy                           0.85     57553
#    macro avg       0.85      0.85      0.85     57553
# weighted avg       0.85      0.85      0.85     57553

# %%
from sklearn.ensemble import RandomForestClassifier #RandomForestRegressor

fit_rf = RandomForestClassifier(random_state=3)
# Providing the different values of hyperparameters
param_dist = {'max_depth': [2, 3, 4,6,8],
              'max_features': ['log2', 'sqrt'],
              'criterion': ['gini', 'entropy'],
             'n_estimators':[10,15,20,25,30]}

# Running gridsearchCV to check for all the different PnCs of these parameter values
cv_rf = GridSearchCV(fit_rf, cv =5,
                     param_grid=param_dist,error_score='raise')

#Fitting the train set , so that grid search is executed on this dataset
cv_rf.fit(x_train, y_train)
print(cv_rf.best_score_)
#prediction
pred = cv_rf.predict(x_test)
y_pred_train = cv_rf.predict(x_train)

#Printing the best parameters by using best_params
print('Best Parameters using grid search: \n', cv_rf.best_params_)   #to get best Hyperparameters
# Out:
# 0.8893541606143966
# Best Parameters using grid search:
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'n_estimators': 30}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
print(classification_report(y_test, pred))
print("*****************************************************\n")
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      7199
#            1       0.86      0.93      0.89      7190
#
#     accuracy                           0.89     14389
#    macro avg       0.89      0.89      0.89     14389
# weighted avg       0.89      0.89      0.89     14389
#
# *****************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89     28772
#            1       0.87      0.94      0.90     28781
#
#     accuracy                           0.90     57553
#    macro avg       0.90      0.90      0.90     57553
# weighted avg       0.90      0.90      0.90     57553

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

error = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,x_train,y_train,cv=7)
    error.append(1-score.mean())

# %%
plt.figure(figsize=(10,6))

plt.plot(range(1,40),error,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier()

param_dist = {'n_neighbors': [21,23,27,29,31,33,35,39],
              'metric': ['minkowski','manhattan']}
cv_knn = GridSearchCV(knn,cv=20,param_grid=param_dist)
cv_knn.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=20, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['minkowski', 'manhattan'],
#                          'n_neighbors': [21, 23, 27, 29, 31, 33, 35, 39]})

# %%
print(cv_knn.best_score_)

y_pred=cv_knn.predict(x_test)
y_pred_train = cv_knn.predict(x_train)
# Out:
# 0.9071292762348238

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
print(classification_report(y_test, y_pred))
print("*****************************************************\n")
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      7199
#            1       0.89      0.93      0.91      7190
#
#     accuracy                           0.91     14389
#    macro avg       0.91      0.91      0.91     14389
# weighted avg       0.91      0.91      0.91     14389
#
# *****************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     28772
#            1       0.90      0.94      0.92     28781
#
#     accuracy                           0.92     57553
#    macro avg       0.92      0.92      0.92     57553
# weighted avg       0.92      0.92      0.92     57553

# %%
from sklearn.model_selection import cross_val_score

scores=cross_val_score(cv_knn,x,y,cv=15)
scores.mean()
# Out:
# 0.8809313725490194

# %%
from sklearn.svm import SVC
svc = SVC(C=5, gamma='auto')

# Train the model
svc.fit(x_train, y_train)
pred = svc.predict(x_test)
pred_train = svc.predict(x_train)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['No Term Deposit','Term Deposit'])
disp.plot()

# %%
print(classification_report(y_test, pred))
print("*****************************************************\n")
print(classification_report(y_train, pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      7199
#            1       0.88      0.92      0.90      7190
#
#     accuracy                           0.90     14389
#    macro avg       0.90      0.90      0.90     14389
# weighted avg       0.90      0.90      0.90     14389
#
# *****************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92     28772
#            1       0.90      0.94      0.92     28781
#
#     accuracy                           0.92     57553
#    macro avg       0.92      0.92      0.92     57553
# weighted avg       0.92      0.92      0.92     57553

# %%
from sklearn.model_selection import cross_val_score

scores=cross_val_score(svc,x,y,cv=15)
scores.mean()
# Out:
# 0.8816421568627448
